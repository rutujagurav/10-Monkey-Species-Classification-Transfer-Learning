# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import math, json, os, sys

# %%
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet50
from keras.optimizers import Adam, SGD
from keras.applications.resnet50 import preprocess_input
from keras import Model, layers
from keras.models import load_model, model_from_json

# %%
keras.backend.backend()
# Out:
# 'tensorflow'

# %%
keras.backend.image_dim_ordering()
# Out:
# 'tf'

# %%
keras.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ### Using weights of ResNet trained on imagenet

# %%
conv_base = ResNet50(
    include_top=False,
    weights='imagenet')

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# C:\Users\rutuj\Anaconda3\envs\deepmlenv\lib\site-packages\keras_applications\resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %% [markdown]
# NOTE: Keras removed the Average pooling layer from ResNet50,
# so we have to add a GlobalAveragePooling Layer
# before we attach a fully connected network at the tail.

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)

# attaching fully connected layers at the tail.
# final dense layer has 10 neurons as we have 10 classes.
#x = layers.Dense(128, activation='relu')(x) 
#predictions = layers.Dense(10, activation='softmax')(x)
model = Model(inputs = conv_base.input, outputs = x)

# %%
import os
path = 'data\\'
images = []
classes = []
for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith('.jpg'):
            images.append(os.path.join(root,file))
            classes.append(root.split('\\')[-1])

# %%
images
# Out:
# ['data\\test\\dummy1.jpg',
#  'data\\test\\n0018.jpg',
#  'data\\test\\n018.jpg',
#  'data\\test\\n0dummy.jpg',
#  'data\\test\\n4016.jpg',
#  'data\\test\\n4017.jpg',
#  'data\\test\\n6dummy.jpg',
#  'data\\training\\n0\\n0018.jpg',
#  'data\\training\\n0\\n0019.jpg',
#  'data\\training\\n0\\n0020.jpg',
#  'data\\training\\n0\\n0021.jpg',
#  'data\\training\\n0\\n0022.jpg',
#  'data\\training\\n0\\n0023.jpg',
#  'data\\training\\n0\\n0024.jpg',
#  'data\\training\\n0\\n0025.jpg',
#  'data\\training\\n0\\n0026.jpg',
#  'data\\training\\n0\\n0027.jpg',
#  'data\\training\\n0\\n0028.jpg',
#  'data\\training\\n0\\n0029.jpg',
#  'data\\training\\n0\\n0030.jpg',
#  'data\\training\\n0\\n0031.jpg',
#  'data\\training\\n0\\n0032.jpg',
#  'data\\training\\n0\\n0033.jpg',
#  'data\\training\\n0\\n0034.jpg',
#  'data\\training\\n0\\n0035.jpg',
#  'data\\training\\n0\\n0036.jpg',
#  'data\\training\\n0\\n0037.jpg',
#  'data\\training\\n0\\n0038.jpg',
#  'data\\training\\n0\\n0039.jpg',
#  'data\\training\\n0\\n0040.jpg',
#  'data\\training\\n0\\n0041.jpg',
#  'data\\training\\n0\\n0042.jpg',
#  'data\\training\\n0\\n0043.jpg',
#  'data\\training\\n0\\n0044.jpg',
#  'data\\training\\n0\\n0045.jpg',
#  'data\\training\\n0\\n0046.jpg',
#  'data\\training\\n0\\n0047.jpg',
#  'data\\training\\n0\\n0048.jpg',
#  'data\\training\\n0\\n0049.jpg',
#  'data\\training\\n0\\n0050.jpg',
#  'data\\training\\n0\\n0051.jpg',
#  'data\\training\\n0\\n0052.jpg',
#  'data\\training\\n0\\n0053.jpg',
#  'data\\training\\n0\\n0110.jpg',
#  'data\\training\\n0\\n0111.jpg',
#  'data\\training\\n0\\n0112.jpg',
#  'data\\training\\n0\\n0113.jpg',
#  'data\\training\\n0\\n0114.jpg',
#  'data\\training\\n0\\n0115.jpg',
#  'data\\training\\n0\\n0116.jpg',
#  'data\\training\\n0\\n0117.jpg',
#  'data\\training\\n0\\n0118.jpg',
#  'data\\training\\n0\\n0119.jpg',
#  'data\\training\\n0\\n0120.jpg',
#  'data\\training\\n0\\n0121.jpg',
#  'data\\training\\n0\\n0122.jpg',
#  'data\\training\\n0\\n0123.jpg',
#  'data\\training\\n0\\n0124.jpg',
#  'data\\training\\n0\\n0125.jpg',
#  'data\\training\\n0\\n0126.jpg',
#  'data\\training\\n0\\n0127.jpg',
#  'data\\training\\n0\\n0128.jpg',
#  'data\\training\\n0\\n0129.jpg',
#  'data\\training\\n0\\n0130.jpg',
#  'data\\training\\n0\\n0131.jpg',
#  'data\\training\\n0\\n0132.jpg',
#  'data\\training\\n0\\n0133.jpg',
#  'data\\training\\n0\\n0134.jpg',
#  'data\\training\\n0\\n0135.jpg',
#  'data\\training\\n0\\n0136.jpg',
#  'data\\training\\n0\\n0137.jpg',
#  'data\\training\\n0\\n0138.jpg',
#  'data\\training\\n0\\n0139.jpg',
#  'data\\training\\n0\\n0140.jpg',
#  'data\\training\\n0\\n0141.jpg',
#  'data\\training\\n0\\n0142.jpg',
#  'data\\training\\n0\\n0143.jpg',
#  'data\\training\\n0\\n0144.jpg',
#  'data\\training\\n0\\n0145.jpg',
#  'data\\training\\n0\\n0146.jpg',
#  'data\\training\\n0\\n0147.jpg',
#  'data\\training\\n0\\n0148.jpg',
#  'data\\training\\n0\\n0149.jpg',
#  'data\\training\\n0\\n0150.jpg',
#  'data\\training\\n0\\n0151.jpg',
#  'data\\training\\n0\\n0152.jpg',
#  'data\\training\\n0\\n0153.jpg',
#  'data\\training\\n0\\n0154.jpg',
#  'data\\training\\n0\\n0155.jpg',
#  'data\\training\\n0\\n0156.jpg',
#  'data\\training\\n0\\n0157.jpg',
#  'data\\training\\n0\\n0158.jpg',
#  'data\\training\\n0\\n0159.jpg',
#  'data\\training\\n0\\n0160.jpg',
#  'data\\training\\n0\\n0161.jpg',
#  'data\\training\\n0\\n0162.jpg',
#  'data\\training\\n0\\n0163.jpg',
#  'data\\training\\n0\\n0164.jpg',
#  'data\\training\\n0\\n0165.jpg',
#  'data\\training\\n0\\n0166.jpg',
#  'data\\training\\n0\\n0167.jpg',
#  'data\\training\\n0\\n0168.jpg',
#  'data\\training\\n0\\n0169.jpg',
#  'data\\training\\n0\\n0170.jpg',
#  'data\\training\\n0\\n0171.jpg',
#  'data\\training\\n0\\n0172.jpg',
#  'data\\training\\n0\\n0173.jpg',
#  'data\\training\\n0\\n0174.jpg',
#  'data\\training\\n0\\n0175.jpg',
#  'data\\training\\n0\\n0176.jpg',
#  'data\\training\\n0\\n018.jpg',
#  'data\\training\\n0\\n019.jpg',
#  'data\\training\\n1\\n1017.jpg',
#  'data\\training\\n1\\n1018.jpg',
#  'data\\training\\n1\\n1019.jpg',
#  'data\\training\\n1\\n1021.jpg',
#  'data\\training\\n1\\n1022.jpg',
#  'data\\training\\n1\\n1023.jpg',
#  'data\\training\\n1\\n1024.jpg',
#  'data\\training\\n1\\n1025.jpg',
#  'data\\training\\n1\\n1026.jpg',
#  'data\\training\\n1\\n1027.jpg',
#  'data\\training\\n1\\n1028.jpg',
#  'data\\training\\n1\\n1029.jpg',
#  'data\\training\\n1\\n1030.jpg',
#  'data\\training\\n1\\n1031.jpg',
#  'data\\training\\n1\\n1032.jpg',
#  'data\\training\\n1\\n1033.jpg',
#  'data\\training\\n1\\n1034.jpg',
#  'data\\training\\n1\\n1035.jpg',
#  'data\\training\\n1\\n1036.jpg',
#  'data\\training\\n1\\n1037.jpg',
#  'data\\training\\n1\\n1038.jpg',
#  'data\\training\\n1\\n1039.jpg',
#  'data\\training\\n1\\n1040.jpg',
#  'data\\training\\n1\\n1041.jpg',
#  'data\\training\\n1\\n1042.jpg',
#  'data\\training\\n1\\n1043.jpg',
#  'data\\training\\n1\\n1044.jpg',
#  'data\\training\\n1\\n1045.jpg',
#  'data\\training\\n1\\n1046.jpg',
#  'data\\training\\n1\\n1047.jpg',
#  'data\\training\\n1\\n1048.jpg',
#  'data\\training\\n1\\n1049.jpg',
#  'data\\training\\n1\\n1050.jpg',
#  'data\\training\\n1\\n1051.jpg',
#  'data\\training\\n1\\n1052.jpg',
#  'data\\training\\n1\\n1053.jpg',
#  'data\\training\\n1\\n1054.jpg',
#  'data\\training\\n1\\n1055.jpg',
#  'data\\training\\n1\\n1056.jpg',
#  'data\\training\\n1\\n1057.jpg',
#  'data\\training\\n1\\n1058.jpg',
#  'data\\training\\n1\\n1059.jpg',
#  'data\\training\\n1\\n1060.jpg',
#  'data\\training\\n1\\n1061.jpg',
#  'data\\training\\n1\\n1062.jpg',
#  'data\\training\\n1\\n1063.jpg',
#  'data\\training\\n1\\n1064.jpg',
#  'data\\training\\n1\\n1065.jpg',
#  'data\\training\\n1\\n1066.jpg',
#  'data\\training\\n1\\n1067.jpg',
#  'data\\training\\n1\\n1068.jpg',
#  'data\\training\\n1\\n1069.jpg',
#  'data\\training\\n1\\n1070.jpg',
#  'data\\training\\n1\\n1071.jpg',
#  'data\\training\\n1\\n1072.jpg',
#  'data\\training\\n1\\n1110.jpg',
#  'data\\training\\n1\\n1111.jpg',
#  'data\\training\\n1\\n1112.jpg',
#  'data\\training\\n1\\n1113.jpg',
#  'data\\training\\n1\\n1114.jpg',
#  'data\\training\\n1\\n1115.jpg',
#  'data\\training\\n1\\n1116.jpg',
#  'data\\training\\n1\\n1117.jpg',
#  'data\\training\\n1\\n1118.jpg',
#  'data\\training\\n1\\n1119.jpg',
#  'data\\training\\n1\\n1120.jpg',
#  'data\\training\\n1\\n1121.jpg',
#  'data\\training\\n1\\n1122.jpg',
#  'data\\training\\n1\\n1123.jpg',
#  'data\\training\\n1\\n1124.jpg',
#  'data\\training\\n1\\n1125.jpg',
#  'data\\training\\n1\\n1126.jpg',
#  'data\\training\\n1\\n1127.jpg',
#  'data\\training\\n1\\n1128.jpg',
#  'data\\training\\n1\\n1129.jpg',
#  'data\\training\\n1\\n1130.jpg',
#  'data\\training\\n1\\n1131.jpg',
#  'data\\training\\n1\\n1132.jpg',
#  'data\\training\\n1\\n1133.jpg',
#  'data\\training\\n1\\n1134.jpg',
#  'data\\training\\n1\\n1135.jpg',
#  'data\\training\\n1\\n1136.jpg',
#  'data\\training\\n1\\n1137.jpg',
#  'data\\training\\n1\\n1138.jpg',
#  'data\\training\\n1\\n1139.jpg',
#  'data\\training\\n1\\n1140.jpg',
#  'data\\training\\n1\\n1141.jpg',
#  'data\\training\\n1\\n1142.jpg',
#  'data\\training\\n1\\n1143.jpg',
#  'data\\training\\n1\\n1144.jpg',
#  'data\\training\\n1\\n1145.jpg',
#  'data\\training\\n1\\n1146.jpg',
#  'data\\training\\n1\\n1147.jpg',
#  'data\\training\\n1\\n1148.jpg',
#  'data\\training\\n1\\n1149.jpg',
#  'data\\training\\n1\\n1150.jpg',
#  'data\\training\\n1\\n1151.jpg',
#  'data\\training\\n1\\n1152.jpg',
#  'data\\training\\n1\\n1153.jpg',
#  'data\\training\\n1\\n1154.jpg',
#  'data\\training\\n1\\n1155.jpg',
#  'data\\training\\n1\\n1156.jpg',
#  'data\\training\\n1\\n1157.jpg',
#  'data\\training\\n1\\n1158.jpg',
#  'data\\training\\n1\\n1159.jpg',
#  'data\\training\\n1\\n1160.jpg',
#  'data\\training\\n1\\n1161.jpg',
#  'data\\training\\n1\\n1162.jpg',
#  'data\\training\\n1\\n1163.jpg',
#  'data\\training\\n1\\n1164.jpg',
#  'data\\training\\n1\\n1165.jpg',
#  'data\\training\\n2\\n2017.jpg',
#  'data\\training\\n2\\n2018.jpg',
#  'data\\training\\n2\\n2019.jpg',
#  'data\\training\\n2\\n2020.jpg',
#  'data\\training\\n2\\n2021.jpg',
#  'data\\training\\n2\\n2022.jpg',
#  'data\\training\\n2\\n2023.jpg',
#  'data\\training\\n2\\n2024.jpg',
#  'data\\training\\n2\\n2025.jpg',
#  'data\\training\\n2\\n2026.jpg',
#  'data\\training\\n2\\n2027.jpg',
#  'data\\training\\n2\\n2028.jpg',
#  'data\\training\\n2\\n2029.jpg',
#  'data\\training\\n2\\n2030.jpg',
#  'data\\training\\n2\\n2031.jpg',
#  'data\\training\\n2\\n2032.jpg',
#  'data\\training\\n2\\n2033.jpg',
#  'data\\training\\n2\\n2034.jpg',
#  'data\\training\\n2\\n2035.jpg',
#  'data\\training\\n2\\n2036.jpg',
#  'data\\training\\n2\\n2037.jpg',
#  'data\\training\\n2\\n2038.jpg',
#  'data\\training\\n2\\n2039.jpg',
#  'data\\training\\n2\\n2040.jpg',
#  'data\\training\\n2\\n2041.jpg',
#  'data\\training\\n2\\n2042.jpg',
#  'data\\training\\n2\\n2043.jpg',
#  'data\\training\\n2\\n2044.jpg',
#  'data\\training\\n2\\n2045.jpg',
#  'data\\training\\n2\\n2046.jpg',
#  'data\\training\\n2\\n2047.jpg',
#  'data\\training\\n2\\n2048.jpg',
#  'data\\training\\n2\\n2049.jpg',
#  'data\\training\\n2\\n2050.jpg',
#  'data\\training\\n2\\n2051.jpg',
#  'data\\training\\n2\\n2052.jpg',
#  'data\\training\\n2\\n2053.jpg',
#  'data\\training\\n2\\n2054.jpg',
#  'data\\training\\n2\\n2055.jpg',
#  'data\\training\\n2\\n2056.jpg',
#  'data\\training\\n2\\n2057.jpg',
#  'data\\training\\n2\\n2058.jpg',
#  'data\\training\\n2\\n2059.jpg',
#  'data\\training\\n2\\n2060.jpg',
#  'data\\training\\n2\\n2061.jpg',
#  'data\\training\\n2\\n2062.jpg',
#  'data\\training\\n2\\n2063.jpg',
#  'data\\training\\n2\\n2064.jpg',
#  'data\\training\\n2\\n2065.jpg',
#  'data\\training\\n2\\n2066.jpg',
#  'data\\training\\n2\\n2067.jpg',
#  'data\\training\\n2\\n2068.jpg',
#  'data\\training\\n2\\n2069.jpg',
#  'data\\training\\n2\\n2110.jpg',
#  'data\\training\\n2\\n2111.jpg',
#  'data\\training\\n2\\n2112.jpg',
#  'data\\training\\n2\\n2113.jpg',
#  'data\\training\\n2\\n2114.jpg',
#  'data\\training\\n2\\n2115.jpg',
#  'data\\training\\n2\\n2116.jpg',
#  'data\\training\\n2\\n2117.jpg',
#  'data\\training\\n2\\n2118.jpg',
#  'data\\training\\n2\\n2119.jpg',
#  'data\\training\\n2\\n2120.jpg',
#  'data\\training\\n2\\n2121.jpg',
#  'data\\training\\n2\\n2122.jpg',
#  'data\\training\\n2\\n2123.jpg',
#  'data\\training\\n2\\n2124.jpg',
#  'data\\training\\n2\\n2125.jpg',
#  'data\\training\\n2\\n2126.jpg',
#  'data\\training\\n2\\n2127.jpg',
#  'data\\training\\n2\\n2128.jpg',
#  'data\\training\\n2\\n2129.jpg',
#  'data\\training\\n2\\n2130.jpg',
#  'data\\training\\n2\\n2131.jpg',
#  'data\\training\\n2\\n2132.jpg',
#  'data\\training\\n2\\n2133.jpg',
#  'data\\training\\n2\\n2134.jpg',
#  'data\\training\\n2\\n2135.jpg',
#  'data\\training\\n2\\n2136.jpg',
#  'data\\training\\n2\\n2137.jpg',
#  'data\\training\\n2\\n2138.jpg',
#  'data\\training\\n2\\n2139.jpg',
#  'data\\training\\n2\\n2140.jpg',
#  'data\\training\\n2\\n2141.jpg',
#  'data\\training\\n2\\n2142.jpg',
#  'data\\training\\n2\\n2143.jpg',
#  'data\\training\\n2\\n2144.jpg',
#  'data\\training\\n2\\n2145.jpg',
#  'data\\training\\n2\\n2146.jpg',
#  'data\\training\\n2\\n2147.jpg',
#  'data\\training\\n2\\n2148.jpg',
#  'data\\training\\n2\\n2149.jpg',
#  'data\\training\\n2\\n2150.jpg',
#  'data\\training\\n2\\n2151.jpg',
#  'data\\training\\n2\\n2152.jpg',
#  'data\\training\\n2\\n2153.jpg',
#  'data\\training\\n2\\n2154.jpg',
#  'data\\training\\n2\\n2155.jpg',
#  'data\\training\\n2\\n2156.jpg',
#  'data\\training\\n2\\n2157.jpg',
#  'data\\training\\n2\\n2158.jpg',
#  'data\\training\\n2\\n2159.jpg',
#  'data\\training\\n2\\n2160.jpg',
#  'data\\training\\n2\\n2161.jpg',
#  'data\\training\\n2\\n2162.jpg',
#  'data\\training\\n2\\n2163.jpg',
#  'data\\training\\n2\\n2164.jpg',
#  'data\\training\\n2\\n2165.jpg',
#  'data\\training\\n2\\n2166.jpg',
#  'data\\training\\n3\\n3020.jpg',
#  'data\\training\\n3\\n3021.jpg',
#  'data\\training\\n3\\n3022.jpg',
#  'data\\training\\n3\\n3023.jpg',
#  'data\\training\\n3\\n3024.jpg',
#  'data\\training\\n3\\n3025.jpg',
#  'data\\training\\n3\\n3026.jpg',
#  'data\\training\\n3\\n3027.jpg',
#  'data\\training\\n3\\n3028.jpg',
#  'data\\training\\n3\\n3029.jpg',
#  'data\\training\\n3\\n3030.jpg',
#  'data\\training\\n3\\n3031.jpg',
#  'data\\training\\n3\\n3032.jpg',
#  'data\\training\\n3\\n3033.jpg',
#  'data\\training\\n3\\n3034.jpg',
#  'data\\training\\n3\\n3035.jpg',
#  'data\\training\\n3\\n3036.jpg',
#  'data\\training\\n3\\n3037.jpg',
#  'data\\training\\n3\\n3038.jpg',
#  'data\\training\\n3\\n3039.jpg',
#  'data\\training\\n3\\n3040.jpg',
#  'data\\training\\n3\\n3041.jpg',
#  'data\\training\\n3\\n3042.jpg',
#  'data\\training\\n3\\n3043.jpg',
#  'data\\training\\n3\\n3044.jpg',
#  'data\\training\\n3\\n3045.jpg',
#  'data\\training\\n3\\n3046.jpg',
#  'data\\training\\n3\\n3047.jpg',
#  'data\\training\\n3\\n3048.jpg',
#  'data\\training\\n3\\n3049.jpg',
#  'data\\training\\n3\\n3050.jpg',
#  'data\\training\\n3\\n3051.jpg',
#  'data\\training\\n3\\n3052.jpg',
#  'data\\training\\n3\\n3053.jpg',
#  'data\\training\\n3\\n3054.jpg',
#  'data\\training\\n3\\n3055.jpg',
#  'data\\training\\n3\\n3056.jpg',
#  'data\\training\\n3\\n3057.jpg',
#  'data\\training\\n3\\n3058.jpg',
#  'data\\training\\n3\\n3059.jpg',
#  'data\\training\\n3\\n3060.jpg',
#  'data\\training\\n3\\n3061.jpg',
#  'data\\training\\n3\\n3062.jpg',
#  'data\\training\\n3\\n3063.jpg',
#  'data\\training\\n3\\n3064.jpg',
#  'data\\training\\n3\\n3065.jpg',
#  'data\\training\\n3\\n3066.jpg',
#  'data\\training\\n3\\n3067.jpg',
#  'data\\training\\n3\\n3068.jpg',
#  'data\\training\\n3\\n3069.jpg',
#  'data\\training\\n3\\n3070.jpg',
#  'data\\training\\n3\\n3071.jpg',
#  'data\\training\\n3\\n3072.jpg',
#  'data\\training\\n3\\n3073.jpg',
#  'data\\training\\n3\\n3074.jpg',
#  'data\\training\\n3\\n3075.jpg',
#  'data\\training\\n3\\n3076.jpg',
#  'data\\training\\n3\\n3077.jpg',
#  'data\\training\\n3\\n3078.jpg',
#  'data\\training\\n3\\n3110.jpg',
#  'data\\training\\n3\\n3111.jpg',
#  'data\\training\\n3\\n3112.jpg',
#  'data\\training\\n3\\n3113.jpg',
#  'data\\training\\n3\\n3114.jpg',
#  'data\\training\\n3\\n3115.jpg',
#  'data\\training\\n3\\n3116.jpg',
#  'data\\training\\n3\\n3117.jpg',
#  'data\\training\\n3\\n3118.jpg',
#  'data\\training\\n3\\n3119.jpg',
#  'data\\training\\n3\\n3120.jpg',
#  'data\\training\\n3\\n3121.jpg',
#  'data\\training\\n3\\n3122.jpg',
#  'data\\training\\n3\\n3123.jpg',
#  'data\\training\\n3\\n3124.jpg',
#  'data\\training\\n3\\n3125.jpg',
#  'data\\training\\n3\\n3126.jpg',
#  'data\\training\\n3\\n3127.jpg',
#  'data\\training\\n3\\n3128.jpg',
#  'data\\training\\n3\\n3129.jpg',
#  'data\\training\\n3\\n3130.jpg',
#  'data\\training\\n3\\n3131.jpg',
#  'data\\training\\n3\\n3132.jpg',
#  'data\\training\\n3\\n3133.jpg',
#  'data\\training\\n3\\n3134.jpg',
#  'data\\training\\n3\\n3135.jpg',
#  'data\\training\\n3\\n3136.jpg',
#  'data\\training\\n3\\n3137.jpg',
#  'data\\training\\n3\\n3138.jpg',
#  'data\\training\\n3\\n3139.jpg',
#  'data\\training\\n3\\n3140.jpg',
#  'data\\training\\n3\\n3141.jpg',
#  'data\\training\\n3\\n3142.jpg',
#  'data\\training\\n3\\n3143.jpg',
#  'data\\training\\n3\\n3144.jpg',
#  'data\\training\\n3\\n3145.jpg',
#  'data\\training\\n3\\n3146.jpg',
#  'data\\training\\n3\\n3147.jpg',
#  'data\\training\\n3\\n3148.jpg',
#  'data\\training\\n3\\n3149.jpg',
#  'data\\training\\n3\\n3150.jpg',
#  'data\\training\\n3\\n3151.jpg',
#  'data\\training\\n3\\n3152.jpg',
#  'data\\training\\n3\\n3153.jpg',
#  'data\\training\\n3\\n3154.jpg',
#  'data\\training\\n3\\n3155.jpg',
#  'data\\training\\n3\\n3156.jpg',
#  'data\\training\\n3\\n3157.jpg',
#  'data\\training\\n3\\n3158.jpg',
#  'data\\training\\n3\\n3159.jpg',
#  'data\\training\\n3\\n3160.jpg',
#  'data\\training\\n3\\n3161.jpg',
#  'data\\training\\n3\\n3162.jpg',
#  'data\\training\\n3\\n3163.jpg',
#  'data\\training\\n3\\n3164.jpg',
#  'data\\training\\n3\\n3165.jpg',
#  'data\\training\\n3\\n3166.jpg',
#  'data\\training\\n3\\n3167.jpg',
#  'data\\training\\n3\\n3168.jpg',
#  'data\\training\\n3\\n3169.jpg',
#  'data\\training\\n3\\n3170.jpg',
#  'data\\training\\n3\\n3171.jpg',
#  'data\\training\\n3\\n3172.jpg',
#  'data\\training\\n4\\n4016.jpg',
#  'data\\training\\n4\\n4017.jpg',
#  'data\\training\\n4\\n4018.jpg',
#  'data\\training\\n4\\n4019.jpg',
#  'data\\training\\n4\\n4020.jpg',
#  'data\\training\\n4\\n4021.jpg',
#  'data\\training\\n4\\n4022.jpg',
#  'data\\training\\n4\\n4023.jpg',
#  'data\\training\\n4\\n4024.jpg',
#  'data\\training\\n4\\n4025.jpg',
#  'data\\training\\n4\\n4026.jpg',
#  'data\\training\\n4\\n4027.jpg',
#  'data\\training\\n4\\n4028.jpg',
#  'data\\training\\n4\\n4029.jpg',
#  'data\\training\\n4\\n4030.jpg',
#  'data\\training\\n4\\n4031.jpg',
#  'data\\training\\n4\\n4032.jpg',
#  'data\\training\\n4\\n4033.jpg',
#  'data\\training\\n4\\n4034.jpg',
#  'data\\training\\n4\\n4035.jpg',
#  'data\\training\\n4\\n4036.jpg',
#  'data\\training\\n4\\n4037.jpg',
#  'data\\training\\n4\\n4038.jpg',
#  'data\\training\\n4\\n4039.jpg',
#  'data\\training\\n4\\n4040.jpg',
#  'data\\training\\n4\\n4041.jpg',
#  'data\\training\\n4\\n4042.jpg',
#  'data\\training\\n4\\n4043.jpg',
#  'data\\training\\n4\\n4044.jpg',
#  'data\\training\\n4\\n4045.jpg',
#  'data\\training\\n4\\n4046.jpg',
#  'data\\training\\n4\\n4047.jpg',
#  'data\\training\\n4\\n4048.jpg',
#  'data\\training\\n4\\n4049.jpg',
#  'data\\training\\n4\\n4050.jpg',
#  'data\\training\\n4\\n4051.jpg',
#  'data\\training\\n4\\n4052.jpg',
#  'data\\training\\n4\\n4053.jpg',
#  'data\\training\\n4\\n4054.jpg',
#  'data\\training\\n4\\n4055.jpg',
#  'data\\training\\n4\\n4056.jpg',
#  'data\\training\\n4\\n4057.jpg',
#  'data\\training\\n4\\n4058.jpg',
#  'data\\training\\n4\\n4059.jpg',
#  'data\\training\\n4\\n4060.jpg',
#  'data\\training\\n4\\n4061.jpg',
#  'data\\training\\n4\\n4062.jpg',
#  'data\\training\\n4\\n4063.jpg',
#  'data\\training\\n4\\n4064.jpg',
#  'data\\training\\n4\\n4110.jpg',
#  'data\\training\\n4\\n4111.jpg',
#  'data\\training\\n4\\n4112.jpg',
#  'data\\training\\n4\\n4113.jpg',
#  'data\\training\\n4\\n4114.jpg',
#  'data\\training\\n4\\n4115.jpg',
#  'data\\training\\n4\\n4116.jpg',
#  'data\\training\\n4\\n4117.jpg',
#  'data\\training\\n4\\n4118.jpg',
#  'data\\training\\n4\\n4119.jpg',
#  'data\\training\\n4\\n4120.jpg',
#  'data\\training\\n4\\n4121.jpg',
#  'data\\training\\n4\\n4122.jpg',
#  'data\\training\\n4\\n4123.jpg',
#  'data\\training\\n4\\n4124.jpg',
#  'data\\training\\n4\\n4125.jpg',
#  'data\\training\\n4\\n4126.jpg',
#  'data\\training\\n4\\n4127.jpg',
#  'data\\training\\n4\\n4128.jpg',
#  'data\\training\\n4\\n4129.jpg',
#  'data\\training\\n4\\n4130.jpg',
#  'data\\training\\n4\\n4131.jpg',
#  'data\\training\\n4\\n4132.jpg',
#  'data\\training\\n4\\n4133.jpg',
#  'data\\training\\n4\\n4134.jpg',
#  'data\\training\\n4\\n4135.jpg',
#  'data\\training\\n4\\n4136.jpg',
#  'data\\training\\n4\\n4137.jpg',
#  'data\\training\\n4\\n4138.jpg',
#  'data\\training\\n4\\n4139.jpg',
#  'data\\training\\n4\\n4140.jpg',
#  'data\\training\\n4\\n4141.jpg',
#  'data\\training\\n4\\n4142.jpg',
#  'data\\training\\n4\\n4143.jpg',
#  'data\\training\\n4\\n4144.jpg',
#  'data\\training\\n4\\n4145.jpg',
#  'data\\training\\n4\\n4146.jpg',
#  'data\\training\\n4\\n4147.jpg',
#  'data\\training\\n4\\n4148.jpg',
#  'data\\training\\n4\\n4149.jpg',
#  'data\\training\\n4\\n4150.jpg',
#  'data\\training\\n4\\n4151.jpg',
#  'data\\training\\n4\\n4152.jpg',
#  'data\\training\\n4\\n4153.jpg',
#  'data\\training\\n4\\n4154.jpg',
#  'data\\training\\n4\\n4155.jpg',
#  'data\\training\\n4\\n41556.jpg',
#  'data\\training\\n4\\n41557.jpg',
#  'data\\training\\n4\\n41558.jpg',
#  'data\\training\\n4\\n41559.jpg',
#  'data\\training\\n4\\n41560.jpg',
#  'data\\training\\n4\\n41561.jpg',
#  'data\\training\\n4\\n41562.jpg',
#  'data\\training\\n4\\n41563.jpg',
#  'data\\training\\n4\\n41564.jpg',
#  'data\\training\\n4\\n41565.jpg',
#  'data\\training\\n5\\n5018.jpg',
#  'data\\training\\n5\\n5019.jpg',
#  'data\\training\\n5\\n5020.jpg',
#  'data\\training\\n5\\n5021.jpg',
#  'data\\training\\n5\\n5022.jpg',
#  'data\\training\\n5\\n5023.jpg',
#  'data\\training\\n5\\n5024.jpg',
#  'data\\training\\n5\\n5025.jpg',
#  'data\\training\\n5\\n5026.jpg',
#  'data\\training\\n5\\n5027.jpg',
#  'data\\training\\n5\\n5028.jpg',
#  'data\\training\\n5\\n5029.jpg',
#  'data\\training\\n5\\n5030.jpg',
#  'data\\training\\n5\\n5031.jpg',
#  'data\\training\\n5\\n5032.jpg',
#  'data\\training\\n5\\n5033.jpg',
#  'data\\training\\n5\\n5034.jpg',
#  'data\\training\\n5\\n5035.jpg',
#  'data\\training\\n5\\n5036.jpg',
#  'data\\training\\n5\\n5037.jpg',
#  'data\\training\\n5\\n5038.jpg',
#  'data\\training\\n5\\n5039.jpg',
#  'data\\training\\n5\\n5040.jpg',
#  'data\\training\\n5\\n5041.jpg',
#  'data\\training\\n5\\n5042.jpg',
#  'data\\training\\n5\\n5043.jpg',
#  'data\\training\\n5\\n5044.jpg',
#  'data\\training\\n5\\n5045.jpg',
#  'data\\training\\n5\\n5046.jpg',
#  'data\\training\\n5\\n5047.jpg',
#  'data\\training\\n5\\n5048.jpg',
#  'data\\training\\n5\\n5049.jpg',
#  'data\\training\\n5\\n5050.jpg',
#  'data\\training\\n5\\n5051.jpg',
#  'data\\training\\n5\\n5052.jpg',
#  'data\\training\\n5\\n5053.jpg',
#  'data\\training\\n5\\n5054.jpg',
#  'data\\training\\n5\\n5055.jpg',
#  'data\\training\\n5\\n5056.jpg',
#  'data\\training\\n5\\n5057.jpg',
#  'data\\training\\n5\\n5058.jpg',
#  'data\\training\\n5\\n5059.jpg',
#  'data\\training\\n5\\n5060.jpg',
#  'data\\training\\n5\\n5061.jpg',
#  'data\\training\\n5\\n5062.jpg',
#  'data\\training\\n5\\n5063.jpg',
#  'data\\training\\n5\\n5064.jpg',
#  'data\\training\\n5\\n5065.jpg',
#  'data\\training\\n5\\n5066.jpg',
#  'data\\training\\n5\\n5067.jpg',
#  'data\\training\\n5\\n5068.jpg',
#  'data\\training\\n5\\n5069.jpg',
#  'data\\training\\n5\\n5070.jpg',
#  'data\\training\\n5\\n5071.jpg',
#  'data\\training\\n5\\n5072.jpg',
#  'data\\training\\n5\\n5073.jpg',
#  'data\\training\\n5\\n5110.jpg',
#  'data\\training\\n5\\n5111.jpg',
#  'data\\training\\n5\\n5112.jpg',
#  'data\\training\\n5\\n5113.jpg',
#  'data\\training\\n5\\n5114.jpg',
#  'data\\training\\n5\\n5115.jpg',
#  'data\\training\\n5\\n5116.jpg',
#  'data\\training\\n5\\n5117.jpg',
#  'data\\training\\n5\\n5118.jpg',
#  'data\\training\\n5\\n5119.jpg',
#  'data\\training\\n5\\n5120.jpg',
#  'data\\training\\n5\\n5121.jpg',
#  'data\\training\\n5\\n5122.jpg',
#  'data\\training\\n5\\n5123.jpg',
#  'data\\training\\n5\\n5124.jpg',
#  'data\\training\\n5\\n5125.jpg',
#  'data\\training\\n5\\n5126.jpg',
#  'data\\training\\n5\\n5127.jpg',
#  'data\\training\\n5\\n5128.jpg',
#  'data\\training\\n5\\n5129.jpg',
#  'data\\training\\n5\\n5130.jpg',
#  'data\\training\\n5\\n5131.jpg',
#  'data\\training\\n5\\n5132.jpg',
#  'data\\training\\n5\\n5133.jpg',
#  'data\\training\\n5\\n5134.jpg',
#  'data\\training\\n5\\n5135.jpg',
#  'data\\training\\n5\\n5136.jpg',
#  'data\\training\\n5\\n5137.jpg',
#  'data\\training\\n5\\n5138.jpg',
#  'data\\training\\n5\\n5139.jpg',
#  'data\\training\\n5\\n5140.jpg',
#  'data\\training\\n5\\n5141.jpg',
#  'data\\training\\n5\\n5142.jpg',
#  'data\\training\\n5\\n5143.jpg',
#  'data\\training\\n5\\n5144.jpg',
#  'data\\training\\n5\\n5145.jpg',
#  'data\\training\\n5\\n5146.jpg',
#  'data\\training\\n5\\n5147.jpg',
#  'data\\training\\n5\\n5148.jpg',
#  'data\\training\\n5\\n5149.jpg',
#  'data\\training\\n5\\n5150.jpg',
#  'data\\training\\n5\\n5151.jpg',
#  'data\\training\\n5\\n5152.jpg',
#  'data\\training\\n5\\n5153.jpg',
#  'data\\training\\n5\\n5154.jpg',
#  'data\\training\\n5\\n5155.jpg',
#  'data\\training\\n5\\n5156.jpg',
#  'data\\training\\n5\\n5157.jpg',
#  'data\\training\\n5\\n5158.jpg',
#  'data\\training\\n5\\n5159.jpg',
#  'data\\training\\n5\\n5160.jpg',
#  'data\\training\\n5\\n5161.jpg',
#  'data\\training\\n5\\n5162.jpg',
#  'data\\training\\n5\\n5163.jpg',
#  'data\\training\\n5\\n5164.jpg',
#  'data\\training\\n5\\n5165.jpg',
#  'data\\training\\n5\\n5166.jpg',
#  'data\\training\\n6\\n6016.jpg',
#  'data\\training\\n6\\n6017.jpg',
#  'data\\training\\n6\\n6018.jpg',
#  'data\\training\\n6\\n6019.jpg',
#  'data\\training\\n6\\n6020.jpg',
#  'data\\training\\n6\\n6021.jpg',
#  'data\\training\\n6\\n6022.jpg',
#  'data\\training\\n6\\n6023.jpg',
#  'data\\training\\n6\\n6024.jpg',
#  'data\\training\\n6\\n6025.jpg',
#  'data\\training\\n6\\n6026.jpg',
#  'data\\training\\n6\\n6027.jpg',
#  'data\\training\\n6\\n6028.jpg',
#  'data\\training\\n6\\n6029.jpg',
#  'data\\training\\n6\\n6030.jpg',
#  'data\\training\\n6\\n6031.jpg',
#  'data\\training\\n6\\n6032.jpg',
#  'data\\training\\n6\\n6033.jpg',
#  'data\\training\\n6\\n6034.jpg',
#  'data\\training\\n6\\n6035.jpg',
#  'data\\training\\n6\\n6036.jpg',
#  'data\\training\\n6\\n6037.jpg',
#  'data\\training\\n6\\n6038.jpg',
#  'data\\training\\n6\\n6039.jpg',
#  'data\\training\\n6\\n6040.jpg',
#  'data\\training\\n6\\n6041.jpg',
#  'data\\training\\n6\\n6042.jpg',
#  'data\\training\\n6\\n6043.jpg',
#  'data\\training\\n6\\n6044.jpg',
#  'data\\training\\n6\\n6045.jpg',
#  'data\\training\\n6\\n6046.jpg',
#  'data\\training\\n6\\n6047.jpg',
#  'data\\training\\n6\\n6048.jpg',
#  'data\\training\\n6\\n6049.jpg',
#  'data\\training\\n6\\n6050.jpg',
#  'data\\training\\n6\\n6051.jpg',
#  'data\\training\\n6\\n6052.jpg',
#  'data\\training\\n6\\n6053.jpg',
#  'data\\training\\n6\\n6054.jpg',
#  'data\\training\\n6\\n6055.jpg',
#  'data\\training\\n6\\n6056.jpg',
#  'data\\training\\n6\\n6057.jpg',
#  'data\\training\\n6\\n6058.jpg',
#  'data\\training\\n6\\n6059.jpg',
#  'data\\training\\n6\\n6060.jpg',
#  'data\\training\\n6\\n6061.jpg',
#  'data\\training\\n6\\n6062.jpg',
#  'data\\training\\n6\\n6063.jpg',
#  'data\\training\\n6\\n6064.jpg',
#  'data\\training\\n6\\n6065.jpg',
#  'data\\training\\n6\\n6066.jpg',
#  'data\\training\\n6\\n6067.jpg',
#  'data\\training\\n6\\n6068.jpg',
#  'data\\training\\n6\\n6069.jpg',
#  'data\\training\\n6\\n6110.jpg',
#  'data\\training\\n6\\n6111.jpg',
#  'data\\training\\n6\\n6112.jpg',
#  'data\\training\\n6\\n6113.jpg',
#  'data\\training\\n6\\n6114.jpg',
#  'data\\training\\n6\\n6115.jpg',
#  'data\\training\\n6\\n6116.jpg',
#  'data\\training\\n6\\n6117.jpg',
#  'data\\training\\n6\\n6118.jpg',
#  'data\\training\\n6\\n6119.jpg',
#  'data\\training\\n6\\n6120.jpg',
#  'data\\training\\n6\\n6121.jpg',
#  'data\\training\\n6\\n6122.jpg',
#  'data\\training\\n6\\n6123.jpg',
#  'data\\training\\n6\\n6124.jpg',
#  'data\\training\\n6\\n6125.jpg',
#  'data\\training\\n6\\n6126.jpg',
#  'data\\training\\n6\\n6127.jpg',
#  'data\\training\\n6\\n6128.jpg',
#  'data\\training\\n6\\n6129.jpg',
#  'data\\training\\n6\\n6130.jpg',
#  'data\\training\\n6\\n6131.jpg',
#  'data\\training\\n6\\n6132.jpg',
#  'data\\training\\n6\\n6133.jpg',
#  'data\\training\\n6\\n6134.jpg',
#  'data\\training\\n6\\n6135.jpg',
#  'data\\training\\n6\\n6136.jpg',
#  'data\\training\\n6\\n6137.jpg',
#  'data\\training\\n6\\n6138.jpg',
#  'data\\training\\n6\\n6139.jpg',
#  'data\\training\\n6\\n6140.jpg',
#  'data\\training\\n6\\n6141.jpg',
#  'data\\training\\n6\\n6142.jpg',
#  'data\\training\\n6\\n6143.jpg',
#  'data\\training\\n6\\n6144.jpg',
#  'data\\training\\n6\\n6145.jpg',
#  'data\\training\\n6\\n6146.jpg',
#  'data\\training\\n6\\n6147.jpg',
#  'data\\training\\n6\\n6148.jpg',
#  'data\\training\\n6\\n6149.jpg',
#  'data\\training\\n6\\n6150.jpg',
#  'data\\training\\n6\\n6151.jpg',
#  'data\\training\\n6\\n6152.jpg',
#  'data\\training\\n6\\n6153.jpg',
#  'data\\training\\n6\\n6154.jpg',
#  'data\\training\\n6\\n6155.jpg',
#  'data\\training\\n6\\n6156.jpg',
#  'data\\training\\n6\\n6157.jpg',
#  'data\\training\\n6\\n6158.jpg',
#  'data\\training\\n6\\n6159.jpg',
#  'data\\training\\n6\\n6160.jpg',
#  'data\\training\\n6\\n6161.jpg',
#  'data\\training\\n7\\n7019.jpg',
#  'data\\training\\n7\\n702.jpg',
#  'data\\training\\n7\\n7020.jpg',
#  'data\\training\\n7\\n7021.jpg',
#  'data\\training\\n7\\n7022.jpg',
#  'data\\training\\n7\\n7023.jpg',
#  'data\\training\\n7\\n7024.jpg',
#  'data\\training\\n7\\n7025.jpg',
#  'data\\training\\n7\\n7026.jpg',
#  'data\\training\\n7\\n7027.jpg',
#  'data\\training\\n7\\n7028.jpg',
#  'data\\training\\n7\\n7029.jpg',
#  'data\\training\\n7\\n7030.jpg',
#  'data\\training\\n7\\n7031.jpg',
#  'data\\training\\n7\\n7032.jpg',
#  'data\\training\\n7\\n7033.jpg',
#  'data\\training\\n7\\n7034.jpg',
#  'data\\training\\n7\\n7035.jpg',
#  'data\\training\\n7\\n7036.jpg',
#  'data\\training\\n7\\n7037.jpg',
#  'data\\training\\n7\\n7038.jpg',
#  'data\\training\\n7\\n7039.jpg',
#  'data\\training\\n7\\n7040.jpg',
#  'data\\training\\n7\\n7041.jpg',
#  'data\\training\\n7\\n7042.jpg',
#  'data\\training\\n7\\n7043.jpg',
#  'data\\training\\n7\\n7044.jpg',
#  'data\\training\\n7\\n7045.jpg',
#  'data\\training\\n7\\n7046.jpg',
#  'data\\training\\n7\\n7047.jpg',
#  'data\\training\\n7\\n7048.jpg',
#  'data\\training\\n7\\n7049.jpg',
#  'data\\training\\n7\\n7050.jpg',
#  'data\\training\\n7\\n7051.jpg',
#  'data\\training\\n7\\n7052.jpg',
#  'data\\training\\n7\\n7053.jpg',
#  'data\\training\\n7\\n7054.jpg',
#  'data\\training\\n7\\n7055.jpg',
#  'data\\training\\n7\\n7056.jpg',
#  'data\\training\\n7\\n7057.jpg',
#  'data\\training\\n7\\n7058.jpg',
#  'data\\training\\n7\\n7059.jpg',
#  'data\\training\\n7\\n7060.jpg',
#  'data\\training\\n7\\n7061.jpg',
#  'data\\training\\n7\\n7062.jpg',
#  'data\\training\\n7\\n7063.jpg',
#  'data\\training\\n7\\n7064.jpg',
#  'data\\training\\n7\\n7065.jpg',
#  'data\\training\\n7\\n7066.jpg',
#  'data\\training\\n7\\n7067.jpg',
#  'data\\training\\n7\\n7068.jpg',
#  'data\\training\\n7\\n7069.jpg',
#  'data\\training\\n7\\n7070.jpg',
#  'data\\training\\n7\\n7071.jpg',
#  'data\\training\\n7\\n7110.jpg',
#  'data\\training\\n7\\n7111.jpg',
#  'data\\training\\n7\\n7112.jpg',
#  'data\\training\\n7\\n7113.jpg',
#  'data\\training\\n7\\n7114.jpg',
#  'data\\training\\n7\\n7115.jpg',
#  'data\\training\\n7\\n7116.jpg',
#  'data\\training\\n7\\n7117.jpg',
#  'data\\training\\n7\\n7118.jpg',
#  'data\\training\\n7\\n7119.jpg',
#  'data\\training\\n7\\n7120.jpg',
#  'data\\training\\n7\\n7121.jpg',
#  'data\\training\\n7\\n7122.jpg',
#  'data\\training\\n7\\n7123.jpg',
#  'data\\training\\n7\\n7124.jpg',
#  'data\\training\\n7\\n7125.jpg',
#  'data\\training\\n7\\n7126.jpg',
#  'data\\training\\n7\\n7127.jpg',
#  'data\\training\\n7\\n7128.jpg',
#  'data\\training\\n7\\n7129.jpg',
#  'data\\training\\n7\\n7130.jpg',
#  'data\\training\\n7\\n7131.jpg',
#  'data\\training\\n7\\n7132.jpg',
#  'data\\training\\n7\\n7133.jpg',
#  'data\\training\\n7\\n7134.jpg',
#  'data\\training\\n7\\n7135.jpg',
#  'data\\training\\n7\\n7136.jpg',
#  'data\\training\\n7\\n7137.jpg',
#  'data\\training\\n7\\n7138.jpg',
#  'data\\training\\n7\\n7139.jpg',
#  'data\\training\\n7\\n7140.jpg',
#  'data\\training\\n7\\n7141.jpg',
#  'data\\training\\n7\\n7142.jpg',
#  'data\\training\\n7\\n7143.jpg',
#  'data\\training\\n7\\n7144.jpg',
#  'data\\training\\n7\\n7145.jpg',
#  'data\\training\\n7\\n7146.jpg',
#  'data\\training\\n7\\n7147.jpg',
#  'data\\training\\n7\\n7148.jpg',
#  'data\\training\\n7\\n7149.jpg',
#  'data\\training\\n7\\n7150.jpg',
#  'data\\training\\n7\\n7151.jpg',
#  'data\\training\\n7\\n7152.jpg',
#  'data\\training\\n7\\n7153.jpg',
#  'data\\training\\n7\\n7154.jpg',
#  'data\\training\\n7\\n7155.jpg',
#  'data\\training\\n7\\n7156.jpg',
#  'data\\training\\n7\\n7157.jpg',
#  'data\\training\\n7\\n7158.jpg',
#  'data\\training\\n7\\n7159.jpg',
#  'data\\training\\n7\\n7160.jpg',
#  'data\\training\\n7\\n7161.jpg',
#  'data\\training\\n7\\n7162.jpg',
#  'data\\training\\n7\\n7163.jpg',
#  'data\\training\\n7\\n7164.jpg',
#  'data\\training\\n7\\n7165.jpg',
#  'data\\training\\n7\\n7166.jpg',
#  'data\\training\\n7\\n7167.jpg',
#  'data\\training\\n7\\n7168.jpg',
#  'data\\training\\n7\\n7169.jpg',
#  'data\\training\\n8\\n8018.jpg',
#  'data\\training\\n8\\n8019.jpg',
#  'data\\training\\n8\\n8020.jpg',
#  'data\\training\\n8\\n8022.jpg',
#  'data\\training\\n8\\n8023.jpg',
#  'data\\training\\n8\\n8024.jpg',
#  'data\\training\\n8\\n8025.jpg',
#  'data\\training\\n8\\n8026.jpg',
#  'data\\training\\n8\\n8027.jpg',
#  'data\\training\\n8\\n8028.jpg',
#  'data\\training\\n8\\n8029.jpg',
#  'data\\training\\n8\\n8030.jpg',
#  'data\\training\\n8\\n8032.jpg',
#  'data\\training\\n8\\n8033.jpg',
#  'data\\training\\n8\\n8034.jpg',
#  'data\\training\\n8\\n8035.jpg',
#  'data\\training\\n8\\n8036.jpg',
#  'data\\training\\n8\\n8037.jpg',
#  'data\\training\\n8\\n8038.jpg',
#  'data\\training\\n8\\n8039.jpg',
#  'data\\training\\n8\\n8040.jpg',
#  'data\\training\\n8\\n8041.jpg',
#  'data\\training\\n8\\n8042.jpg',
#  'data\\training\\n8\\n8043.jpg',
#  'data\\training\\n8\\n8044.jpg',
#  'data\\training\\n8\\n8045.jpg',
#  'data\\training\\n8\\n8046.jpg',
#  'data\\training\\n8\\n8047.jpg',
#  'data\\training\\n8\\n8048.jpg',
#  'data\\training\\n8\\n8049.jpg',
#  'data\\training\\n8\\n8050.jpg',
#  'data\\training\\n8\\n8051.jpg',
#  'data\\training\\n8\\n8052.jpg',
#  'data\\training\\n8\\n8053.jpg',
#  'data\\training\\n8\\n8054.jpg',
#  'data\\training\\n8\\n8055.jpg',
#  'data\\training\\n8\\n8056.jpg',
#  'data\\training\\n8\\n8057.jpg',
#  'data\\training\\n8\\n8058.jpg',
#  'data\\training\\n8\\n8059.jpg',
#  'data\\training\\n8\\n8060.jpg',
#  'data\\training\\n8\\n8061.jpg',
#  'data\\training\\n8\\n8062.jpg',
#  'data\\training\\n8\\n8063.jpg',
#  'data\\training\\n8\\n8064.jpg',
#  'data\\training\\n8\\n8065.jpg',
#  'data\\training\\n8\\n8066.jpg',
#  'data\\training\\n8\\n8067.jpg',
#  'data\\training\\n8\\n8068.jpg',
#  'data\\training\\n8\\n8069.jpg',
#  'data\\training\\n8\\n8070.jpg',
#  'data\\training\\n8\\n8071.jpg',
#  'data\\training\\n8\\n8072.jpg',
#  'data\\training\\n8\\n8073.jpg',
#  'data\\training\\n8\\n8074.jpg',
#  'data\\training\\n8\\n8075.jpg',
#  'data\\training\\n8\\n8076.jpg',
#  'data\\training\\n8\\n8077.jpg',
#  'data\\training\\n8\\n8078.jpg',
#  'data\\training\\n8\\n8079.jpg',
#  'data\\training\\n8\\n808.jpg',
#  'data\\training\\n8\\n8080.jpg',
#  'data\\training\\n8\\n8110.jpg',
#  'data\\training\\n8\\n8111.jpg',
#  'data\\training\\n8\\n8112.jpg',
#  'data\\training\\n8\\n8113.jpg',
#  'data\\training\\n8\\n8114.jpg',
#  'data\\training\\n8\\n8115.jpg',
#  'data\\training\\n8\\n8116.jpg',
#  'data\\training\\n8\\n8117.jpg',
#  'data\\training\\n8\\n8118.jpg',
#  'data\\training\\n8\\n8119.jpg',
#  'data\\training\\n8\\n8120.jpg',
#  'data\\training\\n8\\n8121.jpg',
#  'data\\training\\n8\\n8122.jpg',
#  'data\\training\\n8\\n8123.jpg',
#  'data\\training\\n8\\n8124.jpg',
#  'data\\training\\n8\\n8125.jpg',
#  'data\\training\\n8\\n8126.jpg',
#  'data\\training\\n8\\n8127.jpg',
#  'data\\training\\n8\\n8128.jpg',
#  'data\\training\\n8\\n8129.jpg',
#  'data\\training\\n8\\n8130.jpg',
#  'data\\training\\n8\\n8131.jpg',
#  'data\\training\\n8\\n8132.jpg',
#  'data\\training\\n8\\n8133.jpg',
#  'data\\training\\n8\\n8134.jpg',
#  'data\\training\\n8\\n8135.jpg',
#  'data\\training\\n8\\n8136.jpg',
#  'data\\training\\n8\\n8137.jpg',
#  'data\\training\\n8\\n8138.jpg',
#  'data\\training\\n8\\n8139.jpg',
#  'data\\training\\n8\\n8140.jpg',
#  'data\\training\\n8\\n8141.jpg',
#  'data\\training\\n8\\n8142.jpg',
#  'data\\training\\n8\\n8143.jpg',
#  'data\\training\\n8\\n8144.jpg',
#  'data\\training\\n8\\n8145.jpg',
#  'data\\training\\n8\\n8146.jpg',
#  'data\\training\\n8\\n8147.jpg',
#  'data\\training\\n8\\n8148.jpg',
#  'data\\training\\n8\\n8149.jpg',
#  'data\\training\\n8\\n8150.jpg',
#  'data\\training\\n8\\n8151.jpg',
#  'data\\training\\n8\\n817.jpg',
#  'data\\training\\n8\\n818.jpg',
#  'data\\training\\n9\\n9014.jpg',
#  ...]

# %%
classes
# Out:
# ['test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'test',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n0',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n1',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n2',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n3',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n4',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n5',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n6',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n7',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n8',
#  'n9',
#  ...]

# %%
from keras.preprocessing import image
img_path = images[0]
img = image.load_img(img_path, target_size=(224, 224))
img_data = image.img_to_array(img)
img_data = np.expand_dims(img_data, axis=0)
img_data = preprocess_input(img_data)

feature_vector = model.predict(img_data)

# %%
feature_vector.shape
# Out:
# (1, 2048)

# %%
len(feature_vector[0])
# Out:
# 2048

# %%
len(images)
# Out:
# 1375

# %%
import csv
with open('feature-vectors.csv','w', newline='') as f:
    writer = csv.writer(f)
    for item in images:
        img = image.load_img(item, target_size=(224,224))
        img_data = image.img_to_array(img)
        img_data = np.expand_dims(img_data, axis=0)
        img_data = preprocess_input(img_data)
        feature_vector = model.predict(img_data)
        writer.writerow(feature_vector[0])

# %%
with open('feature-vectors-labels.csv','w',newline='') as l:
    writer = csv.writer(l)
    for label in classes:
        writer.writerow([label])
